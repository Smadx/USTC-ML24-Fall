# %%
from datasets import load_dataset

datasets = load_dataset("Rosykunai/SGEMM_GPU_performance")

data = datasets["train"].to_pandas()

data.describe().T
# Out:
# Using the latest cached version of the dataset since Rosykunai/SGEMM_GPU_performance couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\Rosyk\.cache\huggingface\datasets\Rosykunai___sgemm_gpu_performance\default\0.0.0\9236da4e4fdde23db34f248921014d0addd90106 (last modified on Fri Aug 30 15:05:20 2024).
#                       count           mean           std      min       25%  \
# MWG                193349.0      75.691191     41.976732  16.0000     32.00
# NWG                193349.0      75.733229     42.005083  16.0000     32.00
# KWG                193349.0      25.592602      7.839894  16.0000     16.00
# MDIMC              193349.0      14.470041      8.106851   8.0000      8.00
# NDIMC              193349.0      14.479351      8.111725   8.0000      8.00
# MDIMA              193349.0      17.390356      9.372809   8.0000      8.00
# NDIMB              193349.0      17.382247      9.369417   8.0000      8.00
# ...
